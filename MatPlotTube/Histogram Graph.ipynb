# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(10 , 60 , (50) )
print(x)
# Out:
# [46 56 55 59 22 50 34 58 55 24 58 46 37 28 28 37 44 40 48 47 11 27 20 40
#  24 10 22 32 24 26 25 30 53 58 35 31 54 48 45 26 33 45 50 31 14 23 48 43
#  53 35]

# %%
import matplotlib.pyplot as plt

x = [46, 56, 55, 59, 22, 50, 34, 58, 55, 24, 58, 16, 37, 28, 28, 17, 44, 40, 18 , 47, 11, 27, 20, 40, 24, 10, 22, 32, 24, 26, 25, 30, 53, 58, 35, 31]
len = [10 , 20 ,30 ,40 ,50 , 60]


plt.hist(x , color = "r" , edgecolor = "black" , bins = len)
#plt.hist(x , "auto" , (0, 100) , edgecolor = "r")


plt.title("Histogram Plot graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
